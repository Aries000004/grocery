# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sklearn.datasets as datasets
from sklearn.cluster import KMeans

# %%
# 无监督学习
X_train, target = datasets.make_blobs(200, centers=4)

# %%
km = KMeans(n_clusters=4)

# %%
# 训练
km.fit(X_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
y_ = km.predict(X_train)
y_
# Out:
# array([2, 3, 0, 2, 3, 0, 3, 2, 0, 2, 2, 1, 0, 3, 3, 3, 0, 2, 2, 2, 1, 0,
#        3, 2, 0, 3, 0, 0, 0, 0, 1, 1, 2, 3, 3, 1, 2, 0, 2, 2, 3, 0, 2, 0,
#        3, 2, 2, 2, 1, 0, 0, 1, 3, 3, 0, 1, 1, 3, 2, 0, 1, 3, 1, 0, 1, 1,
#        2, 0, 2, 1, 3, 1, 2, 1, 0, 2, 3, 1, 2, 1, 0, 0, 3, 3, 2, 1, 1, 1,
#        0, 3, 0, 3, 3, 2, 2, 0, 1, 1, 0, 2, 2, 0, 3, 2, 0, 3, 1, 2, 3, 3,
#        2, 3, 0, 0, 1, 1, 1, 0, 1, 3, 2, 3, 2, 1, 3, 2, 1, 0, 2, 2, 2, 2,
#        0, 2, 3, 0, 0, 0, 0, 3, 1, 1, 3, 1, 0, 0, 3, 3, 1, 0, 3, 3, 1, 1,
#        2, 3, 1, 1, 0, 1, 1, 1, 3, 0, 2, 3, 1, 3, 1, 3, 2, 1, 3, 0, 2, 0,
#        3, 0, 3, 1, 2, 1, 1, 3, 1, 0, 0, 1, 0, 2, 0, 3, 2, 2, 1, 2, 2, 3,
#        3, 2])

# %%
centers_ = km.cluster_centers_
centers_
# Out:
# array([[-0.25161677,  5.94154943],
#        [ 8.6592606 , -3.86586038],
#        [-7.08623274,  8.64226925],
#        [ 0.21244383, -0.33953883]])

# %%
plt.figure(figsize=(12,6))

plt.subplot(121)
plt.scatter(X_train[:, 0], X_train[:, 1], c=target)

# 绘制 kmeans 的结果
plt.subplot(122)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_)
